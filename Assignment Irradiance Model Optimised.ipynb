# %%
import pandas as pd 
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module=r"sklearn\.compose\._target")

import numpy as np

from pathlib import Path
from time import perf_counter

from sklearn.model_selection import TimeSeriesSplit
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler
from sklearn.feature_selection import SelectKBest, mutual_info_regression
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# -----------------------------
# Config
# -----------------------------
DATA_PATH = Path(r"C:\Users\jbats\OneDrive\Documents\Year2 Sem2\ENG2112\Assignment\Preprocessed_Solar_Power_Data_v3.csv")
cons_col = "TOTALDEMAND"
irr_col  = "ALLSKY_SFC_SW_DWN"

irr_lag_max = 24     # irradiance lags
dem_lag_max = 24     # demand AR lags

n_splits_cv   = 3
random_state  = 42

#hyperparameters
K_LIST = [10, 15, 20, 25, 30, 40, 50, 60]
WEIGHTS_LIST = ["uniform", "distance"]

t0 = perf_counter()
df = pd.read_csv(DATA_PATH)

#Lag features
for L in range(1, irr_lag_max + 1):
    df[f"irr_lag_{L}"] = df[irr_col].shift(L)
for L in range(1, dem_lag_max + 1):
    df[f"dem_lag_{L}"] = df[cons_col].shift(L)

df = df.dropna().reset_index(drop=True)

#features
exog_cols = [
    "T2M", "T2MDEW", "T2MWET", "RH2M", "PS", "WS2M",
    "Basel Wind Gust", "Basel Wind Direction [10 m]",
    "Basel Precipitation Total", "Basel Wind Speed [10 m]", "Basel Cloud Cover Total",
    "HOUR_SIN", "HOUR_COS", "WEEKDAY_SIN", "WEEKDAY_COS",
]
irr_lags = [f"irr_lag_{i}" for i in range(1, irr_lag_max + 1)]
dem_lags = [f"dem_lag_{i}" for i in range(1, dem_lag_max + 1)]

feat_cols = [c for c in exog_cols + irr_lags + dem_lags if c in df.columns]
X = df[feat_cols].astype("float32")
y = df[cons_col].astype("float32")
print(f"Feature matrix shape: {X.shape}  | Target length: {len(y)}")

#Fixed settings for reduced runtime
k_select = min(50, max(25, X.shape[1] // 2))
pca_components = min(20, k_select)            

#Pipeline
def make_pipe(n_neighbors:int, weights:str) -> Pipeline:
    return Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", RobustScaler()),
        ("select", SelectKBest(score_func=mutual_info_regression, k=k_select)),
        ("pca", PCA(n_components=pca_components, svd_solver="auto", random_state=random_state)),
        ("knn", KNeighborsRegressor(n_neighbors=n_neighbors, weights=weights, algorithm="auto",  metric="minkowski", p=2)),
    ])

#TSCV grid search 
tscv = TimeSeriesSplit(n_splits=n_splits_cv)

def cv_mse(pipe: Pipeline) -> float:
    """Mean MSE across TSCV folds; returns inf if a fold errors."""
    mses = []
    for tr, te in tscv.split(X):
        try:
            pipe.fit(X.iloc[tr], y.iloc[tr].values)
            pred = pipe.predict(X.iloc[te])
            mses.append(mean_squared_error(y.iloc[te].values, pred))
        except Exception as e:
            return float("inf")
    return float(np.mean(mses))

best_cfg = None
best_mse = np.inf

for w in WEIGHTS_LIST:
    for k in K_LIST:
        pipe = make_pipe(n_neighbors=k, weights=w)
        mse = cv_mse(pipe)
        print(f"  k={k:2d}, weights={w:<8s} -> CV MSE={mse:,.1f}")
        if mse < best_mse:
            best_mse = mse
            best_cfg = (k, w)

#if best_cfg is None or not np.isfinite(best_mse):
#   raise RuntimeError("Search failed to find a valid configuration.")

k_best, w_best = best_cfg
print(f"\nBest config: k={k_best}, weights={w_best}  (CV MSE={best_mse:,.1f})")

best_model = make_pipe(n_neighbors=k_best, weights=w_best)

def eval_regression(y_true, y_pred, label=""):
    mse = mean_squared_error(y_true, y_pred)
    rmse = float(np.sqrt(mse))
    mae = mean_absolute_error(y_true, y_pred)
    r2  = r2_score(y_true, y_pred)
    print(f"[{label}] MSE={mse:.2f}  RMSE={rmse:.2f}  MAE={mae:.2f}  R²={r2:.3f}")
    return {"MSE": mse, "RMSE": rmse, "MAE": mae, "R2": r2}

print("\nFold-by-fold performance of best model:")
for i, (tr, te) in enumerate(tscv.split(X), 1):
    best_model.fit(X.iloc[tr], y.iloc[tr].values)
    pred = best_model.predict(X.iloc[te])
    _ = eval_regression(y.iloc[te].values, pred, f"Fold {i}")
# Out:
# Feature matrix shape: (48072, 63)  | Target length: 48072
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 97
#      95 for k in K_LIST:
#      96     pipe = make_pipe(n_neighbors=k, weights=w)
# ---> 97     mse = cv_mse(pipe)
#      98     print(f"  k={k:2d}, weights={w:<8s} -> CV MSE={mse:,.1f}")
#      99     if mse < best_mse:
#
# Cell In[4], line 84, in cv_mse(pipe)
#      82 for tr, te in tscv.split(X):
#      83     try:
# ---> 84         pipe.fit(X.iloc[tr], y.iloc[tr].values)
#      85         pred = pipe.predict(X.iloc[te])
#      86         mses.append(mean_squared_error(y.iloc[te].values, pred))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\pipeline.py:655, in Pipeline.fit(self, X, y, **params)
#     648     raise ValueError(
#     649         "The `transform_input` parameter can only be set if metadata "
#     650         "routing is enabled. You can enable metadata routing using "
#     651         "`sklearn.set_config(enable_metadata_routing=True)`."
#     652     )
#     654 routed_params = self._check_method_params(method="fit", props=params)
# --> 655 Xt = self._fit(X, y, routed_params, raw_params=params)
#     656 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     657     if self._final_estimator != "passthrough":
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\pipeline.py:589, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     582 # Fit or load from cache the current transformer
#     583 step_params = self._get_metadata_for_step(
#     584     step_idx=step_idx,
#     585     step_params=routed_params[name],
#     586     all_params=raw_params,
#     587 )
# --> 589 X, fitted_transformer = fit_transform_one_cached(
#     590     cloned_transformer,
#     591     X,
#     592     y,
#     593     weight=None,
#     594     message_clsname="Pipeline",
#     595     message=self._log_message(step_idx),
#     596     params=step_params,
#     597 )
#     598 # Replace the transformer of the step with the fitted
#     599 # transformer. This is necessary when loading the transformer
#     600 # from the cache.
#     601 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\memory.py:326, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     325 def __call__(self, *args, **kwargs):
# --> 326     return self.func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\pipeline.py:1540, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1538 with _print_elapsed_time(message_clsname, message):
#    1539     if hasattr(transformer, "fit_transform"):
# -> 1540         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1541     else:
#    1542         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1543             X, **params.get("transform", {})
#    1544         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:897, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     894     return self.fit(X, **fit_params).transform(X)
#     895 else:
#     896     # fit method of arity 2 (supervised transformation)
# --> 897     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_selection\_univariate_selection.py:568, in _BaseFilter.fit(self, X, y)
#     563     X, y = validate_data(
#     564         self, X, y, accept_sparse=["csr", "csc"], multi_output=True
#     565     )
#     567 self._check_params(X, y)
# --> 568 score_func_ret = self.score_func(X, y)
#     569 if isinstance(score_func_ret, (list, tuple)):
#     570     self.scores_, self.pvalues_ = score_func_ret
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_selection\_mutual_info.py:441, in mutual_info_regression(X, y, discrete_features, n_neighbors, copy, random_state, n_jobs)
#     325 @validate_params(
#     326     {
#     327         "X": ["array-like", "sparse matrix"],
#    (...)    345     n_jobs=None,
#     346 ):
#     347     """Estimate mutual information for a continuous target variable.
#     348
#     349     Mutual information (MI) [1]_ between two random variables is a non-negative
#    (...)    439     array([0.117, 2.645, 0.0287])
#     440     """
# --> 441     return _estimate_mi(
#     442         X,
#     443         y,
#     444         discrete_features=discrete_features,
#     445         discrete_target=False,
#     446         n_neighbors=n_neighbors,
#     447         copy=copy,
#     448         random_state=random_state,
#     449         n_jobs=n_jobs,
#     450     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_selection\_mutual_info.py:317, in _estimate_mi(X, y, discrete_features, discrete_target, n_neighbors, copy, random_state, n_jobs)
#     310     y = scale(y, with_mean=False)
#     311     y += (
#     312         1e-10
#     313         * np.maximum(1, np.mean(np.abs(y)))
#     314         * rng.standard_normal(size=n_samples)
#     315     )
# --> 317 mi = Parallel(n_jobs=n_jobs)(
#     318     delayed(_compute_mi)(x, y, discrete_feature, discrete_target, n_neighbors)
#     319     for x, discrete_feature in zip(_iterate_columns(X), discrete_mask)
#     320 )
#     322 return np.array(mi)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\parallel.py:82, in Parallel.__call__(self, iterable)
#      73 warning_filters = warnings.filters
#      74 iterable_with_config_and_warning_filters = (
#      75     (
#      76         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     80     for delayed_func, args, kwargs in iterable
#      81 )
# ---> 82 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\parallel.py:147, in _FuncWrapper.__call__(self, *args, **kwargs)
#     145 with config_context(**config), warnings.catch_warnings():
#     146     warnings.filters = warning_filters
# --> 147     return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_selection\_mutual_info.py:169, in _compute_mi(x, y, x_discrete, y_discrete, n_neighbors)
#     167     return _compute_mi_cd(x, y, n_neighbors)
#     168 else:
# --> 169     return _compute_mi_cc(x, y, n_neighbors)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\feature_selection\_mutual_info.py:66, in _compute_mi_cc(x, y, n_neighbors)
#      63 # KDTree is explicitly fit to allow for the querying of number of
#      64 # neighbors within a specified radius
#      65 kd = KDTree(x, metric="chebyshev")
# ---> 66 nx = kd.query_radius(x, radius, count_only=True, return_distance=False)
#      67 nx = np.array(nx) - 1.0
#      69 kd = KDTree(y, metric="chebyshev")
#
# KeyboardInterrupt:
